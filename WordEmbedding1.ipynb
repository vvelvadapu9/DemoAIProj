# %% [markdown]
# <a href="https://colab.research.google.com/github/vvelvadapu9/DemoAIProj/blob/Dev/WordEmbedding1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install gensim

from gensim.models import Word2Vec
text=["the", "cat", "sits", "on", "the", "mat"], ["the", "dog", "plays", "in", "the", "garden"],["cats", "and", "dogs", "are", "friends"]
#print(text)

model = Word2Vec(text,vector_size=100, window=5, min_count=1, sg=1)
vector = model.wv['cat']
print("Vector for 'Cat':" ,vector)
print(len(vector))
# Out:
# (['the', 'cat', 'sits', 'on', 'the', 'mat'], ['the', 'dog', 'plays', 'in', 'the', 'garden'], ['cats', 'and', 'dogs', 'are', 'friends'])
# Vector for 'Cat': [-0.00950012  0.00956222 -0.00777076 -0.00264551 -0.00490641 -0.0049667
#  -0.00802359 -0.00778358 -0.00455321 -0.00127536 -0.00510299  0.00614054
#  -0.00951662 -0.0053071   0.00943715  0.00699133  0.00767582  0.00423474
#   0.00050709 -0.00598114  0.00601878  0.00263503  0.00769943  0.00639384
#   0.00794257  0.00865741 -0.00989575 -0.0067557   0.00133757  0.0064403
#   0.00737382  0.00551698  0.00766163 -0.00512557  0.00658441 -0.00410837
#  -0.00905534  0.00914168  0.0013314  -0.00275968 -0.00247784 -0.00422048
#   0.00481234  0.00440022 -0.00265336 -0.00734188 -0.00356585 -0.00033661
#   0.00609589 -0.00283734 -0.00012089  0.00087973 -0.00709565  0.002065
#  -0.00143242  0.00280215  0.00484222 -0.00135202 -0.00278014  0.00773865
#   0.0050456   0.00671352  0.00451564  0.00866716  0.00747497 -0.00108189
# ...

# %%
vector = model.wv['the']
print("Vector for 'the':" ,vector)
print(len(vector))
# Out:
# Vector for 'the': [-5.3622725e-04  2.3643136e-04  5.1033497e-03  9.0092728e-03
#  -9.3029495e-03 -7.1168090e-03  6.4588725e-03  8.9729885e-03
#  -5.0154282e-03 -3.7633716e-03  7.3805046e-03 -1.5334714e-03
#  -4.5366134e-03  6.5540518e-03 -4.8601604e-03 -1.8160177e-03
#   2.8765798e-03  9.9187379e-04 -8.2852151e-03 -9.4488179e-03
#   7.3117660e-03  5.0702621e-03  6.7576934e-03  7.6286553e-04
#   6.3508903e-03 -3.4053659e-03 -9.4640139e-04  5.7685734e-03
#  -7.5216377e-03 -3.9361035e-03 -7.5115822e-03 -9.3004224e-04
#   9.5381187e-03 -7.3191668e-03 -2.3337686e-03 -1.9377411e-03
#   8.0774371e-03 -5.9308959e-03  4.5162440e-05 -4.7537340e-03
#  -9.6035507e-03  5.0072931e-03 -8.7595852e-03 -4.3918253e-03
#  -3.5099984e-05 -2.9618145e-04 -7.6612402e-03  9.6147433e-03
#   4.9820580e-03  9.2331432e-03 -8.1579173e-03  4.4957981e-03
#  -4.1370760e-03  8.2453608e-04  8.4986202e-03 -4.4621765e-03
#   4.5175003e-03 -6.7869602e-03 -3.5484887e-03  9.3985079e-03
# ...

# %%
#Find the most similar words to 'cat'
similar_words = model.wv.most_similar('cat', topn=5)
print("Most similar words to 'cat':", similar_words)
print(len(similar_words))
# Out:
# Most similar words to 'cat': [('and', 0.25290459394454956), ('friends', 0.13725271821022034), ('cats', 0.04410674050450325), ('garden', 0.01281161978840828), ('dogs', 0.006598459556698799)]
# 5

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
text = "the quick brown fox jumps over the lazy dog"
print(text)
# Out:
# the quick brown fox jumps over the lazy dog

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
# Parts of Speech (POS) tagging

nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
from nltk import pos_tag
pos_tags = pos_tag(tokens)
pos_tags
# Out:
# [('the', 'DT'),
#  ('quick', 'JJ'),
#  ('brown', 'NN'),
#  ('fox', 'NN'),
#  ('jumps', 'VBZ'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('lazy', 'JJ'),
#  ('dog', 'NN')]

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
text = """
Barack Obama was born on August 4, 1961, in Honolulu, Hawaii.He served as the 44th President of the United States from 2009 to 2017.
Apple Inc., headquartered in Cupertino, California, is a leading technology company.
"""
print(text)
# Out:
# Barack Obama was born on August 4, 1961, in Honolulu, Hawaii.He served as the 44th President of the United States from 2009 to 2017.
# Apple Inc., headquartered in Cupertino, California, is a leading technology company.

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
words = word_tokenize(text)
print(words)
# Out:
# ['Barack', 'Obama', 'was', 'born', 'on', 'August', '4', ',', '1961', ',', 'in', 'Honolulu', ',', 'Hawaii.He', 'served', 'as', 'the', '44th', 'President', 'of', 'the', 'United', 'States', 'from', '2009', 'to', '2017', '.', 'Apple', 'Inc.', ',', 'headquartered', 'in', 'Cupertino', ',', 'California', ',', 'is', 'a', 'leading', 'technology', 'company', '.']

# %%
# Parts of Speech (POS) tagging
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk import pos_tag
pos_tags = pos_tag(words)
print(pos_tags)
# Out:
# [('Barack', 'NNP'), ('Obama', 'NNP'), ('was', 'VBD'), ('born', 'VBN'), ('on', 'IN'), ('August', 'NNP'), ('4', 'CD'), (',', ','), ('1961', 'CD'), (',', ','), ('in', 'IN'), ('Honolulu', 'NNP'), (',', ','), ('Hawaii.He', 'NNP'), ('served', 'VBD'), ('as', 'IN'), ('the', 'DT'), ('44th', 'CD'), ('President', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('from', 'IN'), ('2009', 'CD'), ('to', 'TO'), ('2017', 'CD'), ('.', '.'), ('Apple', 'NNP'), ('Inc.', 'NNP'), (',', ','), ('headquartered', 'VBD'), ('in', 'IN'), ('Cupertino', 'NNP'), (',', ','), ('California', 'NNP'), (',', ','), ('is', 'VBZ'), ('a', 'DT'), ('leading', 'VBG'), ('technology', 'NN'), ('company', 'NN'), ('.', '.')]

# %%
nltk.download('maxent_ne_chunker_tab')
from nltk import ne_chunk
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.

# %%
ner=ne_chunk(pos_tags)
print(ner)
# Out:
# (S
#   (PERSON Barack/NNP)
#   (PERSON Obama/NNP)
#   was/VBD
#   born/VBN
#   on/IN
#   August/NNP
#   4/CD
#   ,/,
#   1961/CD
#   ,/,
#   in/IN
#   (GPE Honolulu/NNP)
#   ,/,
#   Hawaii.He/NNP
#   served/VBD
#   as/IN
#   the/DT
#   44th/CD
#   President/NNP
#   of/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   from/IN
#   2009/CD
#   to/TO
#   2017/CD
#   ./.
#   (PERSON Apple/NNP Inc./NNP)
#   ,/,
#   headquartered/VBD
#   in/IN
#   (GPE Cupertino/NNP)
#   ,/,
#   (GPE California/NNP)
#   ,/,
#   is/VBZ
#   a/DT
#   leading/VBG
#   technology/NN
#   company/NN
#   ./.)
